# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.tools.plotting import andrews_curves
from pandas.tools.plotting import parallel_coordinates
from pandas.tools.plotting import radviz

# %%
Schools = pd.read_csv("Public_Schools.csv")
Schools.head()
# Out:
#            X          Y  OBJECTID_1  OBJECTID  BLDG_ID              BLDG_NAME  \
# 0 -71.004121  42.388799           1         1        1             Guild Bldg
# 1 -71.030480  42.378545           2         2        3        Kennedy, P Bldg
# 2 -71.033891  42.375279           3         3        4              Otis Bldg
# 3 -71.038011  42.378089           4         4        6          Odonnell Bldg
# 4 -71.034921  42.380957           5         5        7  East Boston High Bldg
#
#                ADDRESS         CITY  ZIPCODE  CSP_SCH_ID      ...       \
# 0    195 Leyden Street  East Boston     2128        4061      ...
# 1  343 Saratoga Street  East Boston     2128        4541      ...
# 2    218 Marion Street  East Boston     2128        4322      ...
# 3    33 Trenton Street  East Boston     2128        4543      ...
# 4      86 White Street  East Boston     2128        1070      ...
#
#                SCH_NAME       SCH_LABEL SCH_TYPE SHARED COMPLEX Label  TLT  \
# ...

# %%
Schools.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 21 columns):
# X             131 non-null float64
# Y             131 non-null float64
# OBJECTID_1    131 non-null int64
# OBJECTID      131 non-null int64
# BLDG_ID       131 non-null int64
# BLDG_NAME     131 non-null object
# ADDRESS       131 non-null object
# CITY          131 non-null object
# ZIPCODE       131 non-null int64
# CSP_SCH_ID    131 non-null int64
# SCH_ID        131 non-null int64
# SCH_NAME      131 non-null object
# SCH_LABEL     131 non-null object
# SCH_TYPE      131 non-null object
# SHARED        131 non-null object
# COMPLEX       131 non-null object
# Label         131 non-null int64
# TLT           131 non-null int64
# PL            131 non-null object
# POINT_X       131 non-null float64
# POINT_Y       131 non-null float64
# dtypes: float64(4), int64(8), object(9)
# memory usage: 21.6+ KB

# %%
sns.jointplot(x = "OBJECTID_1", y = "OBJECTID", data = Schools, size = 5)
# Out:
# C:\Users\deerej arun\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\deerej arun\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(Schools, hue = "PL", size = 5)\
     .map(plt.scatter, "OBJECTID_1", "OBJECTID")\
     .add_legend()

# %%
sns.boxplot(x = "PL", y = "OBJECTID_1", data = Schools)

# %%
ax = sns.boxplot(x = "PL", y = "OBJECTID_1", data = Schools)
ax = sns.stripplot(x = "PL", y = "OBJECTID_1", data = Schools, jitter = True, edgecolor = "gray")

# %%
sns.violinplot(x = "PL", y = "OBJECTID_1", data = Schools, size = 6)

# %%
sns.FacetGrid(Schools, hue = "PL", size = 6)\
     .map(sns.kdeplot, "OBJECTID_1")\
     .add_legend()
# Out:
# C:\Users\deerej arun\Anaconda2\lib\site-packages\numpy\core\_methods.py:135: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\deerej arun\Anaconda2\lib\site-packages\numpy\core\_methods.py:127: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\deerej arun\Anaconda2\lib\site-packages\statsmodels\nonparametric\bandwidths.py:20: RuntimeWarning: invalid value encountered in minimum
#   return np.minimum(np.std(X, axis=0, ddof=1), IQR)
# C:\Users\deerej arun\Anaconda2\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\deerej arun\Anaconda2\lib\site-packages\numpy\core\_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)

# %%
sns.pairplot(Schools.drop("OBJECTID",axis = 1), hue = "PL", size = 3)

# %%
sns.pairplot(Schools.drop("OBJECTID", axis = 1), hue = "PL", size = 3, diag_kind = "kde")
# Out:
# C:\Users\deerej arun\Anaconda2\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\deerej arun\Anaconda2\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)

# %%
Schools.drop("OBJECTID", axis = 1).boxplot(by = "PL", figsize = (12, 6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000028BB2AC8>,
# ...
#       dtype=object)
